# %%
import pandas as pd
import os
import re

# %%
heart_file = None
oxygen_file = None

for file in os.listdir("."):
    if re.search("heart", file, re.IGNORECASE):
        heart_file = file
        if oxygen_file is not None:
            break  # both files found, exit loop
    elif re.search("oxygen", file, re.IGNORECASE):
        oxygen_file = file
        if heart_file is not None:
            break  # both files found, exit loop

print("Heart rate file:", heart_file)
print("Oxygen level file:", oxygen_file)
# Out:
# Heart rate file: com.samsung.shealth.tracker.heart_rate.20230501102776.csv
# Oxygen level file: com.samsung.shealth.tracker.oxygen_saturation.20230501102776.csv

# %%
df1=pd.read_csv(heart_file, header=1, na_values=[''], index_col=False)
df2=pd.read_csv(oxygen_file, header=1, na_values=[''], index_col=False)

# %%
df1
# Out:
#      source  tag_id  com.samsung.health.heart_rate.heart_beat_count  \
# 0       NaN   21312                                               1
# 1       NaN   21312                                               1
# 2       NaN   21316                                               1
# 3       NaN   21312                                               1
# 4       NaN   21312                                               1
# ..      ...     ...                                             ...
# 442     NaN   21312                                               1
# 443     NaN   21312                                               1
# 444     NaN   21312                                               1
# 445     NaN   21312                                               1
# 446     NaN   21312                                               1
#
#     com.samsung.health.heart_rate.start_time  \
# 0                    2023-04-24 15:40:58.552
# 1                    2023-04-24 16:40:29.352
# 2                    2023-04-24 17:34:36.722
# 3                    2023-04-24 18:30:29.300
# 4                    2023-04-24 19:40:59.573
# ..                                       ...
# 442                  2023-04-30 13:50:29.314
# 443                  2023-04-30 16:40:29.292
# 444                  2023-04-30 17:40:29.265
# 445                  2023-05-01 01:10:29.326
# 446                  2023-05-01 03:20:29.277
#
#      com.samsung.health.heart_rate.custom  \
# 0                                     NaN
# 1                                     NaN
# 2                                     NaN
# 3                                     NaN
# 4                                     NaN
# ..                                    ...
# 442                                   NaN
# 443                                   NaN
# 444                                   NaN
# 445                                   NaN
# 446                                   NaN
#
#     com.samsung.health.heart_rate.binning_data  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
# 3                                          NaN
# 4                                          NaN
# ..                                         ...
# 442                                        NaN
# 443                                        NaN
# 444                                        NaN
# 445                                        NaN
# 446                                        NaN
#
#     com.samsung.health.heart_rate.update_time  \
# 0                     2023-04-24 15:51:20.961
# 1                     2023-04-24 16:54:55.541
# 2                     2023-04-24 17:35:00.796
# 3                     2023-04-24 18:34:06.794
# 4                     2023-04-24 19:41:00.150
# ..                                        ...
# 442                   2023-04-30 13:54:59.972
# 443                   2023-04-30 16:55:00.057
# 444                   2023-04-30 17:55:00.088
# 445                   2023-05-01 01:14:59.985
# 446                   2023-05-01 03:27:08.009
#
#     com.samsung.health.heart_rate.create_time  \
# 0                     2023-04-24 15:51:20.961
# 1                     2023-04-24 16:54:55.541
# 2                     2023-04-24 16:54:55.886
# 3                     2023-04-24 18:34:06.794
# 4                     2023-04-24 19:41:00.150
# ..                                        ...
# 442                   2023-04-30 13:54:59.972
# 443                   2023-04-30 16:55:00.057
# 444                   2023-04-30 17:55:00.088
# 445                   2023-05-01 01:14:59.985
# 446                   2023-05-01 03:27:08.009
#
#      com.samsung.health.heart_rate.max  com.samsung.health.heart_rate.min  \
# 0                                  NaN                                NaN
# 1                                  NaN                                NaN
# 2                                  NaN                                NaN
# 3                                  NaN                                NaN
# 4                                  NaN                                NaN
# ..                                 ...                                ...
# 442                                NaN                                NaN
# 443                                NaN                                NaN
# 444                                NaN                                NaN
# 445                                NaN                                NaN
# 446                                NaN                                NaN
#
#     com.samsung.health.heart_rate.time_offset  \
# 0                                    UTC-0600
# 1                                    UTC-0600
# 2                                    UTC-0600
# 3                                    UTC-0600
# 4                                    UTC-0600
# ..                                        ...
# 442                                  UTC-0600
# 443                                  UTC-0600
# 444                                  UTC-0600
# 445                                  UTC-0600
# 446                                  UTC-0600
#
#     com.samsung.health.heart_rate.deviceuuid  \
# 0                                 uQ5cDGZ0VS
# 1                                 uQ5cDGZ0VS
# 2                                 uQ5cDGZ0VS
# 3                                 uQ5cDGZ0VS
# 4                                 uQ5cDGZ0VS
# ..                                       ...
# 442                               yUp5hdLGo8
# 443                               yUp5hdLGo8
# 444                               yUp5hdLGo8
# 445                               yUp5hdLGo8
# 446                               yUp5hdLGo8
#
#      com.samsung.health.heart_rate.comment  \
# 0                                      NaN
# 1                                      NaN
# 2                                      NaN
# 3                                      NaN
# 4                                      NaN
# ..                                     ...
# 442                                    NaN
# 443                                    NaN
# 444                                    NaN
# 445                                    NaN
# 446                                    NaN
#
#     com.samsung.health.heart_rate.pkg_name  \
# 0              com.sec.android.app.shealth
# 1              com.sec.android.app.shealth
# 2              com.sec.android.app.shealth
# 3              com.sec.android.app.shealth
# 4              com.sec.android.app.shealth
# ..                                     ...
# 442            com.sec.android.app.shealth
# 443            com.sec.android.app.shealth
# 444            com.sec.android.app.shealth
# 445            com.sec.android.app.shealth
# 446            com.sec.android.app.shealth
#
#     com.samsung.health.heart_rate.end_time  \
# 0                  2023-04-24 15:40:58.552
# 1                  2023-04-24 16:40:29.352
# 2                  2023-04-24 17:34:36.722
# 3                  2023-04-24 18:30:29.300
# 4                  2023-04-24 19:40:59.573
# ..                                     ...
# 442                2023-04-30 13:50:29.314
# 443                2023-04-30 16:40:29.292
# 444                2023-04-30 17:40:29.265
# 445                2023-05-01 01:10:29.326
# 446                2023-05-01 03:20:29.277
#
#     com.samsung.health.heart_rate.datauuid  \
# 0     4a238133-a341-4bbb-87ac-85105570fe44
# 1     b4c8c78b-09c2-40c7-bb87-1b478ce21445
# 2     86bb251c-310a-4343-bbd7-c4980b249437
# 3     25cfbc1b-ad36-4f7b-b827-4b37d0afc2bc
# 4     f4e3258c-5b65-4466-b306-ac10ebcc34c9
# ..                                     ...
# 442   d5e03713-80b4-40ad-8842-059f67b98968
# 443   92d39edc-5b37-4225-bd9c-0ad2ff59dc5f
# 444   57feb3f5-4f3b-4fd4-9796-c43a93a1b99c
# 445   a62c275d-ef87-4445-90aa-9772f0cf3303
# 446   35880a93-7453-4c87-bcd2-512705aef608
#
#      com.samsung.health.heart_rate.heart_rate
# 0                                       101.0
# 1                                        66.0
# 2                                        59.0
# 3                                        66.0
# 4                                        88.0
# ..                                        ...
# 442                                      63.0
# 443                                      68.0
# 444                                      75.0
# 445                                      77.0
# 446                                      76.0
#
# [447 rows x 17 columns]

# %%
df2
# Out:
#    source  tag_id com.samsung.health.oxygen_saturation.start_time  \
# 0     NaN   31301                         2023-04-28 07:55:00.000
# 1     NaN   31301                         2023-04-30 07:38:00.000
# 2     NaN   31301                         2023-04-27 05:45:00.000
#
#    com.samsung.health.oxygen_saturation.custom  \
# 0                                          NaN
# 1                                          NaN
# 2                                          NaN
#
#   com.samsung.health.oxygen_saturation.update_time  \
# 0                          2023-04-28 14:49:03.709
# 1                          2023-04-30 14:29:54.482
# 2                          2023-04-27 14:39:56.458
#
#   com.samsung.health.oxygen_saturation.create_time  \
# 0                          2023-04-28 14:49:03.709
# 1                          2023-04-30 14:29:54.482
# 2                          2023-04-27 14:39:56.458
#
#    com.samsung.health.oxygen_saturation.low_duration  \
# 0                                                270
# 1                                                477
# 2                                                686
#
#         com.samsung.health.oxygen_saturation.binning  \
# 0  0d86edaf-41d7-4305-9fe9-acf704dd0cc7.com.samsu...
# 1  41067a54-c660-4ce0-983d-46e90d658566.com.samsu...
# 2  1d24a151-1711-4375-830d-d8e894110d60.com.samsu...
#
#    com.samsung.health.oxygen_saturation.max  \
# 0                                      96.0
# 1                                      99.0
# 2                                      98.0
#
#    com.samsung.health.oxygen_saturation.min  \
# 0                                      88.0
# 1                                      83.0
# 2                                      84.0
#
#    com.samsung.health.oxygen_saturation.spo2  \
# 0                                       91.0
# 1                                       92.0
# 2                                       91.0
#
#   com.samsung.health.oxygen_saturation.time_offset  \
# 0                                         UTC-0600
# 1                                         UTC-0600
# 2                                         UTC-0600
#
#   com.samsung.health.oxygen_saturation.deviceuuid  \
# 0                                      yUp5hdLGo8
# 1                                      yUp5hdLGo8
# 2                                      yUp5hdLGo8
#
#    com.samsung.health.oxygen_saturation.comment  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
#
#   com.samsung.health.oxygen_saturation.pkg_name  \
# 0                   com.sec.android.app.shealth
# 1                   com.sec.android.app.shealth
# 2                   com.sec.android.app.shealth
#
#   com.samsung.health.oxygen_saturation.end_time  \
# 0                       2023-04-28 14:39:00.000
# 1                       2023-04-30 14:06:00.000
# 2                       2023-04-27 14:32:00.000
#
#   com.samsung.health.oxygen_saturation.datauuid  \
# 0          0d86edaf-41d7-4305-9fe9-acf704dd0cc7
# 1          41067a54-c660-4ce0-983d-46e90d658566
# 2          1d24a151-1711-4375-830d-d8e894110d60
#
#    com.samsung.health.oxygen_saturation.heart_rate
# 0                                              NaN
# 1                                              NaN
# 2                                              NaN

# %%
# Perform an outer join on date1 and date2
combined_df = pd.merge(df1, df2, left_on='com.samsung.health.heart_rate.end_time', right_on='com.samsung.health.oxygen_saturation.end_time', how='outer')

# Create a new column called combodate by combining date1 and date2
combined_df["combodate"] = combined_df["com.samsung.health.heart_rate.end_time"].fillna(combined_df["com.samsung.health.oxygen_saturation.end_time"])

# Drop the original date1 and date2 columns
combined_df = combined_df.drop(["com.samsung.health.heart_rate.end_time", "com.samsung.health.oxygen_saturation.end_time"], axis=1)

# Sort the combined dataframe by combodate
combined_df = combined_df.sort_values(by="combodate")

# Write the sorted dataframe to a new CSV file
combined_df.to_csv("combined_sorted.csv", index=False)
